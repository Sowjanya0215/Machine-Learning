# %%
# !pip install matplotlib pandas
# Out:
# ...
#   Using cached matplotlib-3.10.8-cp310-cp310-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.61.1-cp310-cp310-win_amd64.whl.metadata (116 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp310-cp310-win_amd64.whl.metadata (6.4 kB)
# ...
# Using cached matplotlib-3.10.8-cp310-cp310-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp310-cp310-win_amd64.whl (1.6 MB)
# Using cached kiwisolver-1.4.9-cp310-cp310-win_amd64.whl (73 kB)
# ...
#
#    -------- ------------------------------- 1/5 [fonttools]
#    -------- ------------------------------- 1/5 [fonttools]
#    -------- ------------------------------- 1/5 [fonttools]
#    -------- ------------------------------- 1/5 [fonttools]
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data={"salaries": [10000,30000,25000, 30000, 28000, 35000, 40000]}
df=pd.DataFrame(data)

# %%
plt.hist(df["salaries"])
plt.show()

# %%
plt.boxplot(df["salaries"])
plt.xlabel("num")
plt.show()

# %%
df["dept"]=["HR", "IT", "Finance", "IT", "HR", "Marketing", "Finance"]
df.head()
# Out:
#    salaries     dept
# 0     10000       HR
# 1     30000       IT
# 2     25000  Finance
# 3     30000       IT
# 4     28000       HR

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   salaries  7 non-null      int64
#  1   dept      7 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 240.0+ bytes

# %%
count=df["dept"].value_counts()
count
# Out:
# dept
# HR           2
# IT           2
# Finance      2
# Marketing    1
# Name: count, dtype: int64

# %%
plt.pie(count,labels=count.index,autopct="%1.1f")
plt.show()

# %%
plt.bar(count.index,count,color=["green","pink","red","blue"])
plt.show()

# %%
df["Age"]=[30,40,56,60,78,80,90]
df.head()
# Out:
#    salaries     dept  Age
# 0     10000       HR   30
# 1     30000       IT   40
# 2     25000  Finance   56
# 3     30000       IT   60
# 4     28000       HR   78

# %%
plt.scatter(df["Age"],df["salaries"],color="red")
plt.show()

# %%
plt.plot(df["Age"],df["salaries"],color="red",marker="o",linestyle=":",linewidth="2")
plt.show()
